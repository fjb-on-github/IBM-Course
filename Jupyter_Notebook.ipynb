# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Filip</b>
# <br>
# My desired occupation is a position of a data scientist in the finance industry.

# %% [markdown]
# <i> I am interesting in data science becuase it allows making decision in a way that was not possible before. Levereging high volume of data to analyze and predict certain phenomena is facinating to me and I hope that my future job will revolve around that.

# %% [markdown]
# <h3>My code in the next cell will compare two numbers for equality and return appropriate text.

# %%
x = 1
y = 2
if x == y:
    print("X is equal to Y")
else:
    print("X is not equal to Y")

# %% [markdown]
# IBM TOOLS
# <hr>
# <ol>
#   <li><a href="https://www.ibm.com/nl-en/cloud/watson-studio">IBM Watson Studio</a></li>
#   <li><a href="https://www.ibm.com/docs/en/cloud-paks/cp-data/3.5.0?topic=services-watson-openscale">IBM Watson Open Scale</a></li>
#   <li><a href="https://www.ibm.com/cloud/watson-knowledge-catalog">Watson Knowledge Catalog</a></li>
# </ol>
